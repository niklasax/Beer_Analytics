# %%
#import libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import config

# %%
#sqlalcehmy database connection
database = f'postgres://{config.user}:{config.db_password}@{config.host}/postgres'
engine = create_engine(database)

# %%
beer_db = pd.read_sql_query('''SELECT * FROM beer_data;''', con=engine)
beer_db.head()
# Out:
#      abv   ibu    id                                  name  \
# 0  0.061  60.0  1979                          Bitter Bitch
# 1  0.099  92.0  1036                         Lower De Boom
# 2  0.079  45.0  1024                         Fireside Chat
# 3  0.044  42.0   876                       Bitter American
# 4  0.049  17.0   802  Hell or High Watermelon Wheat (2009)
#
#                      style brewery_id  ounces  brewery_idbrewery_  \
# 0  American Pale Ale (APA)        177    12.0                 177
# 1      American Barleywine        368     8.4                 368
# 2            Winter Warmer        368    12.0                 368
# 3  American Pale Ale (APA)        368    12.0                 368
# 4   Fruit / Vegetable Beer        368    12.0                 368
#
#              namebrewery_           city state
# 0     18th Street Brewery           Gary    IN
# 1  21st Amendment Brewery  San Francisco    CA
# 2  21st Amendment Brewery  San Francisco    CA
# 3  21st Amendment Brewery  San Francisco    CA
# 4  21st Amendment Brewery  San Francisco    CA

# %%
# Seperate dataset into features (X) and target (y)

X = beer_db[['abv', 'ibu']] # Features
y = beer_db['style'] # Target

# splitting the dataset

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Creating scaler instance

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
y_train
# Out:
# 1235         Milk / Sweet Stout
# 908                American IPA
# 1022     Saison / Farmhouse Ale
# 127     American Pale Ale (APA)
# 749     American Pale Ale (APA)
#                  ...
# 423                American IPA
# 392                 Belgian IPA
# 244     American Pale Ale (APA)
# 1336         American White IPA
# 655             Euro Dark Lager
# Name: style, Length: 982, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=1000, n_features=2,
                          n_informative=2, n_redundant=0,
                          random_state=48, shuffle=False)

rfc = RandomForestClassifier(n_estimators=128, random_state=48)
rfc.fit(X_train, y_train)

y_pred=rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
#                                      precision    recall  f1-score   support
#
#                    Abbey Single Ale       0.50      1.00      0.67         1
#                             Altbier       0.00      0.00      0.00         2
#              American Adjunct Lager       0.67      1.00      0.80         4
#            American Amber / Red Ale       0.30      0.40      0.34        20
#          American Amber / Red Lager       0.50      0.17      0.25         6
#                 American Barleywine       0.00      0.00      0.00         0
#                  American Black Ale       0.00      0.00      0.00         5
#                 American Blonde Ale       0.20      0.13      0.16        15
#                  American Brown Ale       0.00      0.00      0.00        11
#             American Dark Wheat Ale       0.00      0.00      0.00         1
#      American Double / Imperial IPA       0.83      0.73      0.78        26
#    American Double / Imperial Stout       0.00      0.00      0.00         0
#                        American IPA       0.72      0.78      0.75       100
#           American India Pale Lager       0.00      0.00      0.00         0
#             American Pale Ale (APA)       0.38      0.58      0.46        43
#                 American Pale Lager       0.00      0.00      0.00         3
#             American Pale Wheat Ale       0.43      0.40      0.42        25
#                    American Pilsner       0.00      0.00      0.00         4
#                     American Porter       0.09      0.12      0.11         8
#                      American Stout       0.00      0.00      0.00         3
#                 American Strong Ale       0.00      0.00      0.00         6
#                  American White IPA       0.00      0.00      0.00         3
#                   American Wild Ale       0.00      0.00      0.00         0
#                       Baltic Porter       0.00      0.00      0.00         1
#                    Belgian Dark Ale       0.00      0.00      0.00         2
#                         Belgian IPA       0.00      0.00      0.00         1
#                    Belgian Pale Ale       0.00      0.00      0.00         3
#             Belgian Strong Pale Ale       0.00      0.00      0.00         1
#                  Berliner Weissbier       0.00      0.00      0.00         0
#                      Bière de Garde       0.00      0.00      0.00         2
#                                Bock       0.00      0.00      0.00         0
#      California Common / Steam Beer       0.00      0.00      0.00         1
#                           Cream Ale       0.50      0.33      0.40         3
#                      Czech Pilsener       0.00      0.00      0.00         5
#           Dortmunder / Export Lager       1.00      0.50      0.67         2
#                              Dubbel       0.00      0.00      0.00         1
#                        Dunkelweizen       0.00      0.00      0.00         1
#                  English Barleywine       0.00      0.00      0.00         2
#                      English Bitter       0.00      0.00      0.00         1
#                   English Brown Ale       0.00      0.00      0.00         3
#               English Dark Mild Ale       0.00      0.00      0.00         1
#        English India Pale Ale (IPA)       0.00      0.00      0.00         1
#                    English Pale Ale       0.00      0.00      0.00         1
#                       English Stout       0.00      0.00      0.00         0
#                     Euro Dark Lager       0.00      0.00      0.00         0
#                     Euro Pale Lager       0.00      0.00      0.00         1
# Extra Special / Strong Bitter (ESB)       1.00      0.17      0.29         6
#              Fruit / Vegetable Beer       0.17      0.10      0.12        10
#                     German Pilsener       0.00      0.00      0.00         5
#                                Gose       0.00      0.00      0.00         1
#                          Hefeweizen       0.00      0.00      0.00         9
#                Herbed / Spiced Beer       0.00      0.00      0.00         1
#                     Irish Dry Stout       0.00      0.00      0.00         1
#                       Irish Red Ale       0.00      0.00      0.00         3
#          Keller Bier / Zwickel Bier       0.00      0.00      0.00         2
#                              Kölsch       0.08      0.12      0.10         8
#                         Light Lager       0.00      0.00      0.00         0
#               Maibock / Helles Bock       0.00      0.00      0.00         0
#                  Milk / Sweet Stout       0.00      0.00      0.00         1
#                 Munich Dunkel Lager       0.00      0.00      0.00         1
#                 Munich Helles Lager       0.00      0.00      0.00         2
#                Märzen / Oktoberfest       0.20      0.12      0.15         8
#                       Oatmeal Stout       1.00      0.33      0.50         3
#                         Pumpkin Ale       0.00      0.00      0.00         2
#                    Quadrupel (Quad)       0.00      0.00      0.00         1
#                              Radler       0.00      0.00      0.00         2
#              Russian Imperial Stout       0.00      0.00      0.00         2
#                            Rye Beer       0.25      0.50      0.33         2
#              Saison / Farmhouse Ale       0.00      0.00      0.00         7
#                         Schwarzbier       0.00      0.00      0.00         1
#              Scotch Ale / Wee Heavy       0.50      0.50      0.50         4
#                        Scottish Ale       0.50      0.67      0.57         3
#                              Tripel       0.50      1.00      0.67         1
#                        Vienna Lager       0.00      0.00      0.00         5
#                           Wheat Ale       0.00      0.00      0.00         1
#                       Winter Warmer       1.00      0.50      0.67         2
#                             Witbier       0.00      0.00      0.00         8
#
#                            accuracy                           0.39       421
#                           macro avg       0.15      0.13      0.13       421
#                        weighted avg       0.38      0.39      0.37       421
#
# Accuracy: 0.38717339667458434
# C:\Users\chrer\anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chrer\anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
tr_sc = pd.concat([X_train,y_train], axis=1)
tr_sc = tr_sc.sort_values(by=['abv', 'ibu'])

# %%
tr_sc.head(20)
# Out:
#         abv   ibu                     style
# 1394  0.028  15.0          American Pilsner
# 1166  0.032  13.0               Light Lager
# 82    0.032  27.0                    Kölsch
# 824   0.034   6.0        Berliner Weissbier
# 19    0.035  11.0        Berliner Weissbier
# 113   0.035  45.0  American Amber / Red Ale
# 795   0.037  10.0               Light Lager
# 742   0.037  21.0                   Witbier
# 741   0.037  34.0           American Porter
# 703   0.038  18.0     English Dark Mild Ale
# 108   0.038  40.0              American IPA
# 283   0.039   9.0        Berliner Weissbier
# 258   0.039  16.0    American Adjunct Lager
# 603   0.039  20.0   American Pale Wheat Ale
# 608   0.039  20.0   American Pale Wheat Ale
# 602   0.039  20.0   American Pale Wheat Ale
# 609   0.039  20.0   American Pale Wheat Ale
# 607   0.039  20.0   American Pale Wheat Ale
# 598   0.039  20.0   American Pale Wheat Ale
# 1363  0.040   5.0                      Gose
